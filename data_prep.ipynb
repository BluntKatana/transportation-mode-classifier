# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Combine data from single experiment into single dataframe
# We have the following data from a single experiment: Accelerometer.csv, Gyroscope.csv, Light.csv, Linear Acceleration.csv, Location.csv, Magnetometer.csv, Pressure.csv, and Temperature.csv.

# %%
# Define the folder path and load the data
FOLDER = "data/Fiets 2024-06-05 10-03-06/"
TRANSPORT_MODE = "bike"

data_files = {
    "accelerometer": "Accelerometer.csv",
    "gyroscope": "Gyroscope.csv",
    "light": "Light.csv",
    "linear_acceleration": "Linear Acceleration.csv",
    "location": "Location.csv",
    "magnetometer": "Magnetometer.csv",
    "pressure": "Pressure.csv",
    "proximity": "Proximity.csv",
    "temperature": "Temperature.csv"
}

dataframes = {}
for name, file in data_files.items():
    dataframes[name] = pd.read_csv(FOLDER + file, delimiter=";")

# %%
# Merge dataframes based on the "Time (s)" column
merged_df = None
for name, df in dataframes.items():
    if merged_df is None:
        merged_df = df
    else:
        merged_df = merged_df.merge(df, how='outer', on='Time (s)')

merged_df.index = merged_df.index.astype(float)

# Save the merged dataframe to a CSV file
merged_df.to_csv(FOLDER + "merged_data.csv", index=False)

# Display the merged dataframe
merged_df.head()
# Out:
#           Time (s) Acceleration x (m/s^2) Acceleration y (m/s^2)  \
# 0.0  0,000000000E0                    NaN                    NaN
# 1.0  1,000055599E2                    NaN                    NaN
# 2.0  1,000104138E2                    NaN                    NaN
# 3.0  1,000121840E2                    NaN                    NaN
# 4.0  1,000245684E2                    NaN                    NaN
#
#     Acceleration z (m/s^2) Gyroscope x (rad/s) Gyroscope y (rad/s)  \
# 0.0                    NaN                 NaN                 NaN
# 1.0                    NaN                 NaN                 NaN
# 2.0                    NaN                 NaN                 NaN
# 3.0                    NaN                 NaN                 NaN
# 4.0                    NaN                 NaN                 NaN
#
#     Gyroscope z (rad/s) Illuminance (lx) Linear Acceleration x (m/s^2)  \
# 0.0                 NaN    1,072459375E4                           NaN
# 1.0                 NaN              NaN                           NaN
# 2.0                 NaN              NaN                           NaN
# 3.0                 NaN              NaN                           NaN
# 4.0                 NaN              NaN                -2,348985672E0
#
#     Linear Acceleration y (m/s^2)  ... Velocity (m/s) Direction (°)  \
# 0.0                           NaN  ...            NaN           NaN
# 1.0                           NaN  ...            NaN           NaN
# 2.0                           NaN  ...            NaN           NaN
# 3.0                           NaN  ...            NaN           NaN
# 4.0                 2,045177460E0  ...            NaN           NaN
#
#     Horizontal Accuracy (m) Vertical Accuracy (m) Magnetic field x (µT)  \
# 0.0           1,265200043E1         1,000000000E0                   NaN
# 1.0                     NaN                   NaN                   NaN
# 2.0                     NaN                   NaN                   NaN
# 3.0                     NaN                   NaN                   NaN
# 4.0                     NaN                   NaN                   NaN
#
#     Magnetic field y (µT) Magnetic field z (µT) Pressure (hPa)  Distance (cm)  \
# 0.0                   NaN                   NaN            NaN            NaN
# 1.0                   NaN                   NaN  1,011350464E3            NaN
# 2.0                   NaN                   NaN            NaN            NaN
# 3.0                   NaN                   NaN            NaN  0,000000000E0
# 4.0                   NaN                   NaN            NaN            NaN
#
#     Temperature (°C)
# 0.0              NaN
# 1.0              NaN
# 2.0    3,279687500E1
# 3.0              NaN
# 4.0              NaN
#
# [5 rows x 24 columns]
